# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Read in the data
# Create a DataFrame
crypto_df = pd.read_csv(Path('Resources/crypto_data.csv'), index_col=0)
crypto_df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42           42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365          365Coin       X11       True   PoW/PoS              NaN
# 404          404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611        SixEleven   SHA-256       True       PoW              NaN
# 808              808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# XBC      BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...              ...
# XBC          1000000
# DVTC       100000000
# GIOT       233100000
# OPSC        21000000
# PUNK        40000000
#
# [1252 rows x 6 columns]

# %%
# Discard all cryptocurrencies that are not being traded
crypto_df = crypto_df[crypto_df['IsTrading'] == True]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...              ...
# SERO      1000000000
# UOS       1000000000
# BDX       1400222610
# ZEN         21000000
# XBC          1000000
#
# [1144 rows x 6 columns]

# %%
# Remove all rows that have at least one null value.
crypto_df.dropna(inplace=True)
crypto_df
# Out:
# C:\Users\matt\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# 1337    EliteCoin          X13       True   PoW/PoS     2.927942e+10
# BTC       Bitcoin      SHA-256       True       PoW     1.792718e+07
# ...           ...          ...        ...       ...              ...
# ZEPH       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# GAP       Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337    314159265359
# BTC         21000000
# ...              ...
# ZEPH      2000000000
# GAP        250000000
# BDX       1400222610
# ZEN         21000000
# XBC          1000000
#
# [685 rows x 6 columns]

# %%
# Check dtypes
crypto_df.dtypes
# Out:
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
# Convert to numeric
crypto_df['TotalCoinSupply'] = pd.to_numeric(crypto_df['TotalCoinSupply'])
crypto_df
# Out:
# C:\Users\matt\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# 1337    EliteCoin          X13       True   PoW/PoS     2.927942e+10
# BTC       Bitcoin      SHA-256       True       PoW     1.792718e+07
# ...           ...          ...        ...       ...              ...
# ZEPH       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# GAP       Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#       TotalCoinSupply
# 42       4.200000e+01
# 404      5.320000e+08
# 808      0.000000e+00
# 1337     3.141593e+11
# BTC      2.100000e+07
# ...               ...
# ZEPH     2.000000e+09
# GAP      2.500000e+08
# BDX      1.400223e+09
# ZEN      2.100000e+07
# XBC      1.000000e+06
#
# [685 rows x 6 columns]

# %%
# Filter for cryptocurrencies that have been mined. That is, the total coins mined should be greater than zero.
crypto_df = crypto_df[crypto_df['TotalCoinSupply'] > 0]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 1337    EliteCoin          X13       True   PoW/PoS     2.927942e+10
# BTC       Bitcoin      SHA-256       True       PoW     1.792718e+07
# LTC      Litecoin       Scrypt       True       PoW     6.303924e+07
# ...           ...          ...        ...       ...              ...
# ZEPH       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# GAP       Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#       TotalCoinSupply
# 42       4.200000e+01
# 404      5.320000e+08
# 1337     3.141593e+11
# BTC      2.100000e+07
# LTC      8.400000e+07
# ...               ...
# ZEPH     2.000000e+09
# GAP      2.500000e+08
# BDX      1.400223e+09
# ZEN      2.100000e+07
# XBC      1.000000e+06
#
# [637 rows x 6 columns]

# %%
# delete the `CoinName` from the original dataframe
crypto_df.drop(columns='CoinName', inplace=True)
crypto_df
# Out:
# C:\Users\matt\.conda\envs\PythonData\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Algorithm  IsTrading ProofType  TotalCoinsMined  TotalCoinSupply
# 42         Scrypt       True   PoW/PoS     4.199995e+01     4.200000e+01
# 404        Scrypt       True   PoW/PoS     1.055185e+09     5.320000e+08
# 1337          X13       True   PoW/PoS     2.927942e+10     3.141593e+11
# BTC       SHA-256       True       PoW     1.792718e+07     2.100000e+07
# LTC        Scrypt       True       PoW     6.303924e+07     8.400000e+07
# ...           ...        ...       ...              ...              ...
# ZEPH      SHA-256       True      DPoS     2.000000e+09     2.000000e+09
# GAP        Scrypt       True   PoW/PoS     1.493105e+07     2.500000e+08
# BDX   CryptoNight       True       PoW     9.802226e+08     1.400223e+09
# ZEN      Equihash       True       PoW     7.296538e+06     2.100000e+07
# XBC        Scrypt       True       PoS     1.283270e+05     1.000000e+06
#
# [637 rows x 5 columns]

# %%
# Create dummy variables for text features
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
X.head()
# Out:
#       IsTrading  TotalCoinsMined  TotalCoinSupply  \
# 42         True     4.199995e+01     4.200000e+01
# 404        True     1.055185e+09     5.320000e+08
# 1337       True     2.927942e+10     3.141593e+11
# BTC        True     1.792718e+07     2.100000e+07
# LTC        True     6.303924e+07     8.400000e+07
#
#       Algorithm_1GB AES Pattern Search  Algorithm_536  Algorithm_Argon2  \
# 42                                   0              0                 0
# 404                                  0              0                 0
# 1337                                 0              0                 0
# BTC                                  0              0                 0
# LTC                                  0              0                 0
#
#       Algorithm_BLAKE256  Algorithm_Blake  Algorithm_Blake2S  \
# 42                     0                0                  0
# 404                    0                0                  0
# 1337                   0                0                  0
# BTC                    0                0                  0
# LTC                    0                0                  0
#
#       Algorithm_Blake2b  ...  ProofType_PoW/PoS  ProofType_PoW/PoS   \
# 42                    0  ...                  1                   0
# 404                   0  ...                  1                   0
# 1337                  0  ...                  1                   0
# BTC                   0  ...                  0                   0
# LTC                   0  ...                  0                   0
#
#       ProofType_PoW/PoW  ProofType_PoW/nPoS  ProofType_Pos  \
# 42                    0                   0              0
# 404                   0                   0              0
# 1337                  0                   0              0
# BTC                   0                   0              0
# LTC                   0                   0              0
#
#       ProofType_Proof of Authority  ProofType_Proof of Trust  ProofType_TPoS  \
# 42                               0                         0               0
# 404                              0                         0               0
# 1337                             0                         0               0
# BTC                              0                         0               0
# LTC                              0                         0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# LTC                                0                   0
#
# [5 rows x 106 columns]

# %%
# Standardize data
X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[ 0.        , -0.09782131, -0.03965512, ..., -0.03965258,
#         -0.03965258, -0.03965258],
#        [ 0.        , -0.07228807, -0.03965497, ..., -0.03965258,
#         -0.03965258, -0.03965258],
#        [ 0.        ,  0.61067897, -0.03956909, ..., -0.03965258,
#         -0.03965258, -0.03965258],
#        ...,
#        [ 0.        , -0.074102  , -0.03965474, ..., -0.03965258,
#         -0.03965258, -0.03965258],
#        [ 0.        , -0.09764475, -0.03965511, ..., -0.03965258,
#         -0.03965258, -0.03965258],
#        [ 0.        , -0.09781821, -0.03965512, ..., -0.03965258,
#         -0.03965258, -0.03965258]])

# %%
# Use PCA to reduce dimensions to 90% principal components
pca = PCA(n_components=0.90)
crypto_pca = pca.fit_transform(X_scaled)

# %%
# Next, further reduce the dataset dimensions with t-SNE and visually inspect the results
# Scale the data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(X_scaled)

# %%
# Run t-SNE
tsne = TSNE(learning_rate=250)
tsne_features = tsne.fit_transform(scaled_features)

# %%
# Prepare to plot the dataset

# The first column of transformed features
crypto_df['x'] = tsne_features[:,0]

# The second column of transformed features
crypto_df['y'] = tsne_features[:,1]
# Out:
# C:\Users\matt\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\matt\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
# Visualize the clusters
plt.scatter(c['x'], crypto_df['y'])
plt.show()

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(crypto_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-4600ecc5a859> in <module>
#       5 for i in k:
#       6     km = KMeans(n_clusters=i, random_state=0)
# ----> 7     km.fit(crypto_df)
#       8     inertia.append(km.inertia_)
#       9
#
# ~\.conda\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
# --> 982                                 accept_large_sparse=False)
#     983
#     984         self._check_params(X)
#
# ~\.conda\envs\PythonData\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\.conda\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\.conda\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\.conda\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~\.conda\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'Scrypt'
